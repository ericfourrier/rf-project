# %% [markdown]
# # Qlearning

# %% [markdown]
# ## Import Packages

# %%
import numpy as np

# %pylab inline --no-import
import pylab as pl
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# Seaborn options 
sns.set_palette("deep", desat=.6)
sns.set_context(rc={"figure.figsize": (12, 8)})
plt.style.use('ggplot') # ggplot2 style for matplotlib
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def geometric_brown(T=10, mu=0.01, sigma=0.1, S0=1, dt=0.01):
    """ Returns a geometric browninan motion"""
    N = int(round(T / dt))
    t = np.linspace(0, T, N)
    W = np.random.standard_normal(size=N)
    W = np.cumsum(W) * np.sqrt(dt)  # standard brownian motion
    X = (mu - 0.5 * sigma ** 2) * t + sigma * W
    return S0 * np.exp(X)  # geometric brownian motion

def shift(arr, n):
    """ shift a one ndarray"""
    e = np.empty_like(arr)
    if n >= 0:
        e[:n] = arr[0]
        e[n:] = arr[:-n]
    else:
        e[n:] = arr[0]
        e[:n] = arr[-n:]
    return e

def sharp_ratio(r):
    """ Return sharp ratio of returns """
    return np.mean(r) / np.std(r)

# %%
class QlearningStock(object):
    def __init__(self, arr):
        self.arr = arr
        self.market_returns = shift(self.arr,1)/self.arr - 1
        self.samples = len(self.arr)
        self.actions = np.array([1,-1]) #long, short
        self.states = np.array([0,1])
        self.nb_actions = len(self.actions)
        self.nb_states = 2 
        self.epsilon = 0.05
        self.risk_free_rate = 0
        self.transaction_cost = 0
        # self.alpha = 0.05
        self.utility_function = sharp_ratio
        self.gamma = 0.95 # discount factor
        self.nmc = 20 # nb of simulations of Monte Carlo
        self.states = np.zeros(self.samples)
        self.q = np.zeros((self.nb_states,self.nb_actions))
        self.rewards = np.zeros(self.samples)
        self.nb_visits = np.zeros((self.nb_states, self.nb_actions))
        self.current_state = np.random.choice(self.states)

    def reset(self):
        self.nb_visits = np.zeros((self.nb_states, self.actions))
        self.current_state = self.random.choice([0,1])

    def get_reward(self, state, next_state, market_return):
        """ Get reward associated at time t"""
        reward =  (1 + self.risk_free_rate * (1-state) + market_return * state  ) * (
        1 - self.transaction_cost * np.abs(next_state - state))
        return reward

#     def update_reward(self, reward, t):
#         """ Update reward at time t"""
#         self.rewards = reward[t]

    def simu_transition(self, action):
        """ Returns simulation of next state based on action and previous state"""
        if action == 1:
            return 1
        if action == -1:
            return 0


    def get_action(self, state):
        """ Select actions with epison greedy Q learning """
        #Epsilon-Greedy
        if np.random.random() < self.epsilon:
            return np.random.choice(self.actions)
        else:
            return 2*np.argmax(self.q[state,:]) -1 # to modify
    
    @staticmethod
    def action_to_postion(action):
        """action to position mapping for the Q matrix"""
        if action == 1:
            return 1
        if action == -1:
            return 0

        

    def qlearning_step(self, verbose=True):
        for i in range(1, self.samples):
            market_return = self.market_returns[i]
            a = self.get_action(self.current_state)  # random action
            a_position = self.action_to_postion(a)
            print("actions : {}".format(a))
            self.nb_visits[self.current_state, a_position] += 1  # update nb_visits
            # simulate transition
            new_state = self.simu_transition(a)
            # get immediate reward
            print(self.current_state, new_state,a)
            self.reward = self.get_reward(self.current_state,new_state,market_return)
            # put reward in rewards to compute utility function
            print(self.reward)
            self.rewards[i] = self.reward 
            # Calculate utility function
            u = self.utility_function(self.rewards[:i+1]) # compute sharp ration until i
            print(u)
            # Compute temporal difference
            td = u + self.gamma * (self.q[new_state, :].max()) - self.q[self.current_state, a_position]
            # Print infos 
            if verbose:
                print("state : {}, new_state : {}, actions : {}, reward :{}, ".format(
                        self.current_state,new_state,a,self.reward))
                print("Q matrix : \n {}".format(self.q))
            self.q[self.current_state, a_position] +=  + (1.0 / self.nb_visits[self.current_state, a_position]) * td
            self.states[i] = new_state
            self.current_state = new_state
    
    def monte_carlo(self, verbose=False):
        """ Perform monte carlo iteration for Q learning """
        for i in range(self.nmc):
            print("Simulation nb : {}".format(i))
            self.qlearning_step(verbose=verbose)
            self.reset() # reset nb_visits and starting point

# %%
brownian = geometric_brown(30)
model = QlearningStock(brownian)
model.epsilon = 0.05

# %%
model.q
# Out:
# array([[ 0.,  0.],
#        [ 0.,  0.]])

# %%
sum(model.states == 1) # normal
# Out:
# 0

# %%
model.qlearning_step()
# Out:
# actions : -1
# (0.0, 0, -1)
# 1.0
# 1.0
# state : 0.0, new_state : 0, actions : -1, reward :1.0,
# Q matrix :
#  [[ 0.  0.]
#  [ 0.  0.]]
# actions : -1
# (0, 0, -1)
# 1.0
# 1.41421356237
# state : 0, new_state : 0, actions : -1, reward :1.0,
# Q matrix :
#  [[ 1.  0.]
#  [ 0.  0.]]
# actions : -1
# (0, 0, -1)
# 1.0
# 1.73205080757
# state : 0, new_state : 0, actions : -1, reward :1.0,
# Q matrix :
#  [[ 1.68210678  0.        ]
#  [ 0.          0.        ]]
# actions : -1
# (0, 0, -1)
# 1.0
# 2.0
# state : 0, new_state : 0, actions : -1, reward :1.0,
# Q matrix :
#  [[ 2.23142194  0.        ]
#  [ 0.          0.        ]]
# actions : -1
# (0, 0, -1)
# 1.0
# 2.2360679775
# state : 0, new_state : 0, actions : -1, reward :1.0,
# Q matrix :
#  [[ 2.70352916  0.        ]
#  [ 0.          0.        ]]
# actions : -1
# (0, 0, -1)
# 1.0
# 2.44948974278
# state : 0, new_state : 0, actions : -1, reward :1.0,
# Q matrix :
#  [[ 3.12370747  0.        ]
#  [ 0.          0.        ]]
# actions : -1
# (0, 0, -1)
# 1.0
# 2.64575131106
# state : 0, new_state : 0, actions : -1, reward :1.0,
# Q matrix :
#  [[ 3.50592486  0.        ]
#  [ 0.          0.        ]]
# actions : -1
# (0, 0, -1)
# 1.0
# 2.82842712475
# state : 0, new_state : 0, actions : -1, reward :1.0,
# Q matrix :
#  [[ 3.85884701  0.        ]
#  [ 0.          0.        ]]
# actions : -1
# (0, 0, -1)
# 1.0
# 3.0
# state : 0, new_state : 0, actions : -1, reward :1.0,
# Q matrix :
#  [[ 4.18828261  0.        ]
#  [ 0.          0.        ]]
# actions : -1
# (0, 0, -1)
# 1.0
# 3.16227766017
# state : 0, new_state : 0, actions : -1, reward :1.0,
# Q matrix :
#  [[ 4.49834771  0.        ]
#  [ 0.          0.        ]]
# actions : 1
# (0, 1, 1)
# 1.0
# 3.31662479036
# state : 0, new_state : 1, actions : 1, reward :1.0,
# Q matrix :
#  [[ 4.79208374  0.        ]
#  [ 0.          0.        ]]
# actions : -1
# (1, 0, -1)
# 1.01849697943
# 3.4635150886
# state : 1, new_state : 0, actions : -1, reward :1.01849697943,
# Q matrix :
#  [[ 4.79208374  3.31662479]
#  [ 0.          0.        ]]
# actions : -1
# (0, 0, -1)
# 1.0
# 3.60494002325
# state : 0, new_state : 0, actions : -1, reward :1.0,
# Q matrix :
#  [[ 4.79208374  3.31662479]
#  [ 8.01599464  0.        ]]
# actions : -1
# (0, 0, -1)
# 1.0
# 3.74102241153
# state : 0, new_state : 0, actions : -1, reward :1.0,
# Q matrix :
#  [[ 5.09802336  3.31662479]
#  [ 8.01599464  0.        ]]
# actions : -1
# (0, 0, -1)
# 1.0
# 3.87232553438
# state : 0, new_state : 0, actions : -1, reward :1.0,
# Q matrix :
#  [[ 5.38853346  3.31662479]
#  [ 8.01599464  0.        ]]
# actions : -1
# (0, 0, -1)
# 1.0
# 3.99932014305
# state : 0, new_state : 0, actions : -1, reward :1.0,
# Q matrix :
#  [[ 5.66567953  3.31662479]
#  [ 8.01599464  0.        ]]
# actions : 1
# (0, 1, 1)
# 1.0
# 4.12240443616
# state : 0, new_state : 1, actions : 1, reward :1.0,
# Q matrix :
#  [[ 5.93111068  3.31662479]
#  [ 8.01599464  0.        ]]
# actions : -1
# (1, 0, -1)
# 1.02412706547
# 4.24080702276
# state : 1, new_state : 0, actions : -1, reward :1.02412706547,
# Q matrix :
#  [[ 5.93111068  7.52711207]
#  [ 8.01599464  0.        ]]
# actions : 1
# (0, 1, 1)
# 1.0
# 4.35700766371
# state : 0, new_state : 1, actions : 1, reward :1.0,
# Q matrix :
#  [[ 5.93111068  7.52711207]
#  [ 9.70377906  0.        ]]
# actions : -1
# (1, 0, -1)
# 1.00382785462
# 4.47019512984
# state : 1, new_state : 0, actions : -1, reward :1.00382785462,
# Q matrix :
#  [[ 5.93111068  9.54327397]
#  [ 9.70377906  0.        ]]
# actions : 1
# (0, 1, 1)
# 1.0
# 4.58057874817
# state : 0, new_state : 1, actions : 1, reward :1.0,
# Q matrix :
#  [[  5.93111068   9.54327397]
#  [ 10.98128784   0.        ]]
# actions : -1
# (1, 0, -1)
# 1.01900514826
# 4.68772403741
# state : 1, new_state : 0, actions : -1, reward :1.01900514826,
# Q matrix :
#  [[  5.93111068  10.91065603]
#  [ 10.98128784   0.        ]]
# actions : 1
# (0, 1, 1)
# 1.0
# 4.7930627642
# state : 0, new_state : 1, actions : 1, reward :1.0,
# Q matrix :
#  [[  5.93111068  10.91065603]
#  [ 11.9991777    0.        ]]
# actions : -1
# (1, 0, -1)
# 1.02755558759
# 4.89468361739
# state : 1, new_state : 0, actions : -1, reward :1.02755558759,
# Q matrix :
#  [[  5.93111068  11.96698114]
#  [ 11.9991777    0.        ]]
# actions : 1
# (0, 1, 1)
# 1.0
# 4.99558408964
# state : 0, new_state : 1, actions : 1, reward :1.0,
# Q matrix :
#  [[  5.93111068  11.96698114]
#  [ 12.8520053    0.        ]]
# actions : -1
# (1, 0, -1)
# 1.00336173951
# 5.09452235607
# state : 1, new_state : 0, actions : -1, reward :1.00336173951,
# Q matrix :
#  [[  5.93111068  12.83998247]
#  [ 12.8520053    0.        ]]
# actions : 1
# (0, 1, 1)
# 1.0
# 5.19153932415
# state : 0, new_state : 1, actions : 1, reward :1.0,
# Q matrix :
#  [[  5.93111068  12.83998247]
#  [ 13.5920887    0.        ]]
# actions : -1
# (1, 0, -1)
# 0.980303891506
# 5.28538496865
# state : 1, new_state : 0, actions : -1, reward :0.980303891506,
# Q matrix :
#  [[  5.93111068  13.59198834]
#  [ 13.5920887    0.        ]]
# actions : 1
# (0, 1, 1)
# 1.0
# 5.37892509597
# state : 0, new_state : 1, actions : 1, reward :1.0,
# Q matrix :
#  [[  5.93111068  13.59198834]
#  [ 14.25004372   0.        ]]
# actions : -1
# (1, 0, -1)
# 0.983926898751
# 5.46992741364
# state : 1, new_state : 0, actions : -1, reward :0.983926898751,
# Q matrix :
#  [[  5.93111068  14.25754813]
#  [ 14.25004372   0.        ]]
# actions : 1
# (0, 1, 1)
# 1.0
# 5.56034104472
# state : 0, new_state : 1, actions : 1, reward :1.0,
# Q matrix :
#  [[  5.93111068  14.25754813]
#  [ 14.84561303   0.        ]]
# actions : -1
# (1, 0, -1)
# 0.991831778254
# 5.64902729846
# state : 1, new_state : 0, actions : -1, reward :0.991831778254,
# Q matrix :
#  [[  5.93111068  14.85822871]
#  [ 14.84561303   0.        ]]
# actions : 1
# (0, 1, 1)
# 1.0
# 5.73661318873
# state : 0, new_state : 1, actions : 1, reward :1.0,
# Q matrix :
#  [[  5.93111068  14.85822871]
#  [ 15.39213875   0.        ]]
# actions : -1
# (1, 0, -1)
# 1.00324536926
# 5.82288270507
# state : 1, new_state : 0, actions : -1, reward :1.00324536926,
# Q matrix :
#  [[  5.93111068  15.40832034]
#  [ 15.39213875   0.        ]]
# actions : 1
# (0, 1, 1)
# 1.0
# 5.90789082595
# state : 0, new_state : 1, actions : 1, reward :1.0,
# Q matrix :
#  [[  5.93111068  15.40832034]
#  [ 15.89900358   0.        ]]
# actions : -1
# (1, 0, -1)
# 1.00163789676
# 5.99170129162
# state : 1, new_state : 0, actions : -1, reward :1.00163789676,
# Q matrix :
#  [[  5.93111068  15.9177407 ]
#  [ 15.89900358   0.        ]]
# actions : 1
# (0, 1, 1)
# 1.0
# 6.07434711415
# state : 0, new_state : 1, actions : 1, reward :1.0,
# Q matrix :
#  [[  5.93111068  15.9177407 ]
#  [ 16.37305371   0.        ]]
# actions : -1
# (1, 0, -1)
# 1.00770384523
# 6.15577847771
# state : 1, new_state : 0, actions : -1, reward :1.00770384523,
# Q matrix :
#  [[  5.93111068  16.39365798]
#  [ 16.37305371   0.        ]]
# actions : 1
# (0, 1, 1)
# 1.0
# 6.23624549276
# state : 0, new_state : 1, actions : 1, reward :1.0,
# Q matrix :
#  [[  5.93111068  16.39365798]
#  [ 16.81944536   0.        ]]
# actions : 1
# (1, 1, 1)
# 1.00093183261
# 6.31569482056
# state : 1, new_state : 1, actions : 1, reward :1.00093183261,
# Q matrix :
#  [[  5.93111068  16.84143188]
#  [ 16.81944536   0.        ]]
# actions : 1
# (1, 1, 1)
# 0.993128296044
# 6.39392463218
# state : 1, new_state : 1, actions : 1, reward :0.993128296044,
# Q matrix :
#  [[  5.93111068  16.84143188]
#  [ 16.81944536  22.29416791]]
# actions : 1
# (1, 1, 1)
# 0.998919502626
# 6.47141328578
# state : 1, new_state : 1, actions : 1, reward :0.998919502626,
# Q matrix :
#  [[  5.93111068  16.84143188]
#  [ 16.81944536  24.93377603]]
# actions : 1
# (1, 1, 1)
# 1.00101553284
# 6.54800522301
# state : 1, new_state : 1, actions : 1, reward :1.00101553284,
# Q matrix :
#  [[  5.93111068  16.84143188]
#  [ 16.81944536  26.67535086]]
# actions : 1
# (1, 1, 1)
# 0.991128750675
# 6.62336217498
# state : 1, new_state : 1, actions : 1, reward :0.991128750675,
# Q matrix :
#  [[  5.93111068  16.84143188]
#  [ 16.81944536  27.97891028]]
# actions : 1
# (1, 1, 1)
# 0.997190079185
# 6.69815602545
# state : 1, new_state : 1, actions : 1, reward :0.997190079185,
# Q matrix :
#  [[  5.93111068  16.84143188]
#  [ 16.81944536  29.02379361]]
# actions : 1
# (1, 1, 1)
# 1.00021834506
# 6.77217312949
# state : 1, new_state : 1, actions : 1, reward :1.00021834506,
# Q matrix :
#  [[  5.93111068  16.84143188]
#  [ 16.81944536  29.898288  ]]
# actions : -1
# (1, 0, -1)
# 1.0020385316
# 6.84538957848
# state : 1, new_state : 0, actions : -1, reward :1.0020385316,
# Q matrix :
#  [[  5.93111068  16.84143188]
#  [ 16.81944536  30.65218211]]
# actions : 1
# (0, 1, 1)
# 1.0
# 6.9178297884
# state : 0, new_state : 1, actions : 1, reward :1.0,
# Q matrix :
#  [[  5.93111068  16.84143188]
#  [ 17.28293032  30.65218211]]
# actions : 1
# (1, 1, 1)
# 1.00207037235
# 6.98952011741
# state : 1, new_state : 1, actions : 1, reward :1.00207037235,
# Q matrix :
#  [[  5.93111068  18.21257266]
#  [ 17.28293032  30.65218211]]
# actions : 1
# (1, 1, 1)
# 0.989749513313
# 7.06003213657
# state : 1, new_state : 1, actions : 1, reward :0.989749513313,
# Q matrix :
#  [[  5.93111068  18.21257266]
#  [ 17.28293032  31.33429598]]
# actions : 1
# (1, 1, 1)
# 0.996776782551
# 7.13022722502
# state : 1, new_state : 1, actions : 1, reward :0.996776782551,
# Q matrix :
#  [[  5.93111068  18.21257266]
#  [ 17.28293032  31.94466458]]
# actions : 1
# (1, 1, 1)
# 1.00706099713
# 7.19965629728
# state : 1, new_state : 1, actions : 1, reward :1.00706099713,
# Q matrix :
#  [[  5.93111068  18.21257266]
#  [ 17.28293032  32.49796398]]
# actions : 1
# (1, 1, 1)
# 0.996073913865
# 7.26847293971
# state : 1, new_state : 1, actions : 1, reward :0.996073913865,
# Q matrix :
#  [[  5.93111068  18.21257266]
#  [ 17.28293032  33.00476017]]
# actions : 1
# (1, 1, 1)
# 1.00239407203
# 7.33671821688
# state : 1, new_state : 1, actions : 1, reward :1.00239407203,
# Q matrix :
#  [[  5.93111068  18.21257266]
#  [ 17.28293032  33.47294641]]
# actions : 1
# (1, 1, 1)
# 0.995330863087
# 7.40423014862
# state : 1, new_state : 1, actions : 1, reward :0.995330863087,
# Q matrix :
#  [[  5.93111068  18.21257266]
#  [ 17.28293032  33.90856725]]
# actions : 1
# (1, 1, 1)
# 1.00410111276
# 7.47120068193
# state : 1, new_state : 1, actions : 1, reward :1.00410111276,
# Q matrix :
#  [[  5.93111068  18.21257266]
#  [ 17.28293032  34.31633881]]
# actions : 1
# (1, 1, 1)
# 1.01235656298
# 7.53711827813
# state : 1, new_state : 1, actions : 1, reward :1.01235656298,
# Q matrix :
#  [[  5.93111068  18.21257266]
#  [ 17.28293032  34.70003105]]
# actions : 1
# (1, 1, 1)
# 1.00205484415
# 7.60294575103
# state : 1, new_state : 1, actions : 1, reward :1.00205484415,
# Q matrix :
#  [[  5.93111068  18.21257266]
#  [ 17.28293032  35.06266335]]
# actions : 1
# (1, 1, 1)
# 0.992207512523
# 7.66791384801
# state : 1, new_state : 1, actions : 1, reward :0.992207512523,
# Q matrix :
#  [[  5.93111068  18.21257266]
#  [ 17.28293032  35.40676997]]
# actions : 1
# (1, 1, 1)
# 0.992138095122
# 7.73233147048
# state : 1, new_state : 1, actions : 1, reward :0.992138095122,
# Q matrix :
#  [[  5.93111068  18.21257266]
#  [ 17.28293032  35.73441305]]
# actions : 1
# (1, 1, 1)
# 0.990956406228
# 7.79613245243
# state : 1, new_state : 1, actions : 1, reward :0.990956406228,
# Q matrix :
#  [[  5.93111068  18.21257266]
#  [ 17.28293032  36.04733993]]
# actions : 1
# (1, 1, 1)
# 1.01483937836
# 7.85898640996
# state : 1, new_state : 1, actions : 1, reward :1.01483937836,
# Q matrix :
#  [[  5.93111068  18.21257266]
#  [ 17.28293032  36.34702821]]
# actions : 1
# (1, 1, 1)
# 0.98971483527
# 7.92162884718
# state : 1, new_state : 1, actions : 1, reward :0.98971483527,
# Q matrix :
#  [[  5.93111068  18.21257266]
#  [ 17.28293032  36.63472511]]
# actions : -1
# (1, 0, -1)
# 1.00524389204
# 7.98417166602
# state : 1, new_state : 0, actions : -1, reward :1.00524389204,
# Q matrix :
#  [[  5.93111068  18.21257266]
#  [ 17.28293032  36.91153841]]
# actions : 1
# (0, 1, 1)
# 1.0
# 8.04630789512
# state : 0, new_state : 1, actions : 1, reward :1.0,
# Q matrix :
#  [[  5.93111068  18.21257266]
#  [ 17.85458642  36.91153841]]
# actions : 1
# (1, 1, 1)
# 1.00935660899
# 8.10766914522
# state : 1, new_state : 1, actions : 1, reward :1.00935660899,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  36.91153841]]
# actions : 1
# (1, 1, 1)
# 0.996475842389
# 8.16878599483
# state : 1, new_state : 1, actions : 1, reward :0.996475842389,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  37.18380329]]
# actions : 1
# (1, 1, 1)
# 0.989209727504
# 8.22897673381
# state : 1, new_state : 1, actions : 1, reward :0.989209727504,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  37.44670312]]
# actions : 1
# (1, 1, 1)
# 0.991154513069
# 8.28889772177
# state : 1, new_state : 1, actions : 1, reward :0.991154513069,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  37.70096878]]
# actions : 1
# (1, 1, 1)
# 0.986860477341
# 8.34797944485
# state : 1, new_state : 1, actions : 1, reward :0.986860477341,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  37.94727067]]
# actions : 1
# (1, 1, 1)
# 0.992564858025
# 8.40715067062
# state : 1, new_state : 1, actions : 1, reward :0.992564858025,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  38.18618237]]
# actions : 1
# (1, 1, 1)
# 1.00416640495
# 8.46608569329
# state : 1, new_state : 1, actions : 1, reward :1.00416640495,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  38.41824814]]
# actions : 1
# (1, 1, 1)
# 1.00036399038
# 8.52467878146
# state : 1, new_state : 1, actions : 1, reward :1.00036399038,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  38.64394377]]
# actions : 1
# (1, 1, 1)
# 0.995583436516
# 8.58277947652
# state : 1, new_state : 1, actions : 1, reward :0.995583436516,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  38.86369316]]
# actions : 1
# (1, 1, 1)
# 1.00137201436
# 8.64057396002
# state : 1, new_state : 1, actions : 1, reward :1.00137201436,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  39.07787364]]
# actions : 1
# (1, 1, 1)
# 0.984452866638
# 8.69691848496
# state : 1, new_state : 1, actions : 1, reward :0.984452866638,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  39.2868324 ]]
# actions : 1
# (1, 1, 1)
# 1.00796579519
# 8.75367434504
# state : 1, new_state : 1, actions : 1, reward :1.00796579519,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  39.49084988]]
# actions : 1
# (1, 1, 1)
# 0.993353757569
# 8.81013758901
# state : 1, new_state : 1, actions : 1, reward :0.993353757569,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  39.69023611]]
# actions : 1
# (1, 1, 1)
# 1.00074044309
# 8.86643407643
# state : 1, new_state : 1, actions : 1, reward :1.00074044309,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  39.88525399]]
# actions : 1
# (1, 1, 1)
# 1.01089950783
# 8.92185192594
# state : 1, new_state : 1, actions : 1, reward :1.01089950783,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  40.07614764]]
# actions : 1
# (1, 1, 1)
# 1.00559670931
# 8.97731142945
# state : 1, new_state : 1, actions : 1, reward :1.00559670931,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  40.26312182]]
# actions : 1
# (1, 1, 1)
# 1.00792366553
# 9.03229382087
# state : 1, new_state : 1, actions : 1, reward :1.00792366553,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  40.44638906]]
# actions : 1
# (1, 1, 1)
# 0.989197082709
# 9.08664684594
# state : 1, new_state : 1, actions : 1, reward :0.989197082709,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  40.62613199]]
# actions : 1
# (1, 1, 1)
# 0.997207169588
# 9.14118497123
# state : 1, new_state : 1, actions : 1, reward :0.997207169588,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  40.8025155 ]]
# actions : 1
# (1, 1, 1)
# 0.993712486242
# 9.19524985033
# state : 1, new_state : 1, actions : 1, reward :0.993712486242,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  40.97571207]]
# actions : 1
# (1, 1, 1)
# 1.0103656966
# 9.24869741632
# state : 1, new_state : 1, actions : 1, reward :1.0103656966,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  41.14586598]]
# actions : 1
# (1, 1, 1)
# 1.0099856722
# 9.30187340957
# state : 1, new_state : 1, actions : 1, reward :1.0099856722,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  41.31310793]]
# actions : 1
# (1, 1, 1)
# 0.999979625596
# 9.35518253322
# state : 1, new_state : 1, actions : 1, reward :0.999979625596,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  41.47756743]]
# actions : 1
# (1, 1, 1)
# 1.00282316474
# 9.40816036988
# state : 1, new_state : 1, actions : 1, reward :1.00282316474,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  41.63937419]]
# actions : 1
# (1, 1, 1)
# 1.00182293097
# 9.46086030134
# state : 1, new_state : 1, actions : 1, reward :1.00182293097,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  41.79863923]]
# actions : 1
# (1, 1, 1)
# 1.00375411628
# 9.51322372935
# state : 1, new_state : 1, actions : 1, reward :1.00375411628,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  41.95546749]]
# actions : 1
# (1, 1, 1)
# 1.00690839748
# 9.56515224465
# state : 1, new_state : 1, actions : 1, reward :1.00690839748,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  42.10995604]]
# actions : -1
# (1, 0, -1)
# 1.01169582652
# 9.61639598646
# state : 1, new_state : 0, actions : -1, reward :1.01169582652,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 17.85458642  42.26219389]]
# actions : 1
# (0, 1, 1)
# 1.0
# 9.66796030118
# state : 0, new_state : 1, actions : 1, reward :1.0,
# Q matrix :
#  [[  5.93111068  19.87255244]
#  [ 18.56396871  42.26219389]]
# actions : 1
# (1, 1, 1)
# 1.0104078814
# 9.71878581205
# state : 1, new_state : 1, actions : 1, reward :1.0104078814,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  42.26219389]]
# actions : 1
# (1, 1, 1)
# 1.00241076422
# 9.76979188496
# state : 1, new_state : 1, actions : 1, reward :1.00241076422,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  42.41430741]]
# actions : 1
# (1, 1, 1)
# 0.987645901646
# 9.8197171504
# state : 1, new_state : 1, actions : 1, reward :0.987645901646,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  42.5642893 ]]
# actions : 1
# (1, 1, 1)
# 1.00053010897
# 9.87020751021
# state : 1, new_state : 1, actions : 1, reward :1.00053010897,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  42.71220281]]
# actions : 1
# (1, 1, 1)
# 0.987757379777
# 9.91963327457
# state : 1, new_state : 1, actions : 1, reward :0.987757379777,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  42.85813861]]
# actions : 1
# (1, 1, 1)
# 1.02346326021
# 9.96698641502
# state : 1, new_state : 1, actions : 1, reward :1.02346326021,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  43.00215206]]
# actions : 1
# (1, 1, 1)
# 0.991661396371
# 10.0162973915
# state : 1, new_state : 1, actions : 1, reward :0.991661396371,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  43.14427713]]
# actions : 1
# (1, 1, 1)
# 0.996779994753
# 10.0656919845
# state : 1, new_state : 1, actions : 1, reward :0.996779994753,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  43.28461791]]
# actions : 1
# (1, 1, 1)
# 0.987592084094
# 10.1140745345
# state : 1, new_state : 1, actions : 1, reward :0.987592084094,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  43.42324003]]
# actions : 1
# (1, 1, 1)
# 1.00884974702
# 10.1626983532
# state : 1, new_state : 1, actions : 1, reward :1.00884974702,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  43.5601868 ]]
# actions : 1
# (1, 1, 1)
# 1.0018387767
# 10.2114347598
# state : 1, new_state : 1, actions : 1, reward :1.0018387767,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  43.69552051]]
# actions : 1
# (1, 1, 1)
# 1.00490257602
# 10.2598505946
# state : 1, new_state : 1, actions : 1, reward :1.00490257602,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  43.82929816]]
# actions : 1
# (1, 1, 1)
# 1.00895807921
# 10.3077747801
# state : 1, new_state : 1, actions : 1, reward :1.00895807921,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  43.96156678]]
# actions : 1
# (1, 1, 1)
# 1.00844973495
# 10.3555195155
# state : 1, new_state : 1, actions : 1, reward :1.00844973495,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  44.09236833]]
# actions : 1
# (1, 1, 1)
# 0.999411128738
# 10.4033457103
# state : 1, new_state : 1, actions : 1, reward :0.999411128738,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  44.22174772]]
# actions : 1
# (1, 1, 1)
# 1.01482853573
# 10.4499271243
# state : 1, new_state : 1, actions : 1, reward :1.01482853573,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  44.34975175]]
# actions : 1
# (1, 1, 1)
# 1.00468871877
# 10.4972448455
# state : 1, new_state : 1, actions : 1, reward :1.00468871877,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  44.47640467]]
# actions : 1
# (1, 1, 1)
# 0.999872056125
# 10.5444216797
# state : 1, new_state : 1, actions : 1, reward :0.999872056125,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  44.60175959]]
# actions : 1
# (1, 1, 1)
# 0.996194178765
# 10.5912795256
# state : 1, new_state : 1, actions : 1, reward :0.996194178765,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  44.72585412]]
# actions : 1
# (1, 1, 1)
# 1.00786545326
# 10.6377810952
# state : 1, new_state : 1, actions : 1, reward :1.00786545326,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  44.84872157]]
# actions : 1
# (1, 1, 1)
# 0.997810339828
# 10.6842894649
# state : 1, new_state : 1, actions : 1, reward :0.997810339828,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  44.97039324]]
# actions : 1
# (1, 1, 1)
# 1.00713923838
# 10.7304348285
# state : 1, new_state : 1, actions : 1, reward :1.00713923838,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  45.09090424]]
# actions : 1
# (1, 1, 1)
# 0.999705675365
# 10.7765827431
# state : 1, new_state : 1, actions : 1, reward :0.999705675365,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  45.21028296]]
# actions : 1
# (1, 1, 1)
# 0.990664643022
# 10.8219805616
# state : 1, new_state : 1, actions : 1, reward :0.990664643022,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  45.32856169]]
# actions : 1
# (1, 1, 1)
# 1.00725791549
# 10.8675184308
# state : 1, new_state : 1, actions : 1, reward :1.00725791549,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  45.44576104]]
# actions : 1
# (1, 1, 1)
# 0.999161488106
# 10.9130720199
# state : 1, new_state : 1, actions : 1, reward :0.999161488106,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  45.56191281]]
# actions : 1
# (1, 1, 1)
# 0.985460531719
# 10.9571664044
# state : 1, new_state : 1, actions : 1, reward :0.985460531719,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  45.67704582]]
# actions : 1
# (1, 1, 1)
# 1.01605716508
# 11.0010721894
# state : 1, new_state : 1, actions : 1, reward :1.01605716508,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  45.79116838]]
# actions : 1
# (1, 1, 1)
# 1.00233605132
# 11.046057381
# state : 1, new_state : 1, actions : 1, reward :1.00233605132,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  45.90430492]]
# actions : 1
# (1, 1, 1)
# 0.991938027339
# 11.0904347924
# state : 1, new_state : 1, actions : 1, reward :0.991938027339,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  46.0164952 ]]
# actions : 1
# (1, 1, 1)
# 1.00643636937
# 11.1348915745
# state : 1, new_state : 1, actions : 1, reward :1.00643636937,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  46.12775609]]
# actions : 1
# (1, 1, 1)
# 1.00561914822
# 11.1792186032
# state : 1, new_state : 1, actions : 1, reward :1.00561914822,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  46.23811239]]
# actions : 1
# (1, 1, 1)
# 0.99247715606
# 11.2231040372
# state : 1, new_state : 1, actions : 1, reward :0.99247715606,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  46.34758539]]
# actions : 1
# (1, 1, 1)
# 1.01745543527
# 11.2656602259
# state : 1, new_state : 1, actions : 1, reward :1.01745543527,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  46.45619179]]
# actions : 1
# (1, 1, 1)
# 0.99938396925
# 11.3095704549
# state : 1, new_state : 1, actions : 1, reward :0.99938396925,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  46.56393698]]
# actions : 1
# (1, 1, 1)
# 0.999347410676
# 11.3533102168
# state : 1, new_state : 1, actions : 1, reward :0.999347410676,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  46.67085809]]
# actions : 1
# (1, 1, 1)
# 0.98409819
# 11.3953007439
# state : 1, new_state : 1, actions : 1, reward :0.98409819,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  46.776973  ]]
# actions : 1
# (1, 1, 1)
# 1.00178843471
# 11.4387088184
# state : 1, new_state : 1, actions : 1, reward :1.00178843471,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  46.88228058]]
# actions : 1
# (1, 1, 1)
# 1.01175687522
# 11.4812759988
# state : 1, new_state : 1, actions : 1, reward :1.01175687522,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  46.98681615]]
# actions : 1
# (1, 1, 1)
# 1.00103554251
# 11.5243605968
# state : 1, new_state : 1, actions : 1, reward :1.00103554251,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  47.09058814]]
# actions : 1
# (1, 1, 1)
# 0.984386844815
# 11.5657278479
# state : 1, new_state : 1, actions : 1, reward :0.984386844815,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  47.19361996]]
# actions : 1
# (1, 1, 1)
# 0.997925476806
# 11.6084415603
# state : 1, new_state : 1, actions : 1, reward :0.997925476806,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  47.29590937]]
# actions : 1
# (1, 1, 1)
# 1.00527495207
# 11.650925834
# state : 1, new_state : 1, actions : 1, reward :1.00527495207,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  47.39748789]]
# actions : 1
# (1, 1, 1)
# 0.991192404763
# 11.6928419375
# state : 1, new_state : 1, actions : 1, reward :0.991192404763,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  47.49836889]]
# actions : 1
# (1, 1, 1)
# 1.00459532897
# 11.7350458022
# state : 1, new_state : 1, actions : 1, reward :1.00459532897,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  47.59856161]]
# actions : 1
# (1, 1, 1)
# 0.997494422978
# 11.7771242576
# state : 1, new_state : 1, actions : 1, reward :0.997494422978,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  47.69808414]]
# actions : 1
# (1, 1, 1)
# 1.01842836208
# 11.8172786306
# state : 1, new_state : 1, actions : 1, reward :1.01842836208,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  47.79694962]]
# actions : 1
# (1, 1, 1)
# 0.988741360773
# 11.8582546956
# state : 1, new_state : 1, actions : 1, reward :0.988741360773,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  47.89515202]]
# actions : 1
# (1, 1, 1)
# 1.00499502681
# 11.8998328759
# state : 1, new_state : 1, actions : 1, reward :1.00499502681,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  47.99271385]]
# actions : 1
# (1, 1, 1)
# 1.00078856103
# 11.9413710298
# state : 1, new_state : 1, actions : 1, reward :1.00078856103,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  48.08965464]]
# actions : 1
# (1, 1, 1)
# 1.00551999596
# 11.9826322883
# state : 1, new_state : 1, actions : 1, reward :1.00551999596,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  48.18598684]]
# actions : 1
# (1, 1, 1)
# 0.992527542029
# 12.0234751103
# state : 1, new_state : 1, actions : 1, reward :0.992527542029,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  48.28172017]]
# actions : 1
# (1, 1, 1)
# 1.01388643289
# 12.0635565031
# state : 1, new_state : 1, actions : 1, reward :1.01388643289,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  48.37686264]]
# actions : 1
# (1, 1, 1)
# 1.00002838003
# 12.1045182122
# state : 1, new_state : 1, actions : 1, reward :1.00002838003,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  48.47141865]]
# actions : 1
# (1, 1, 1)
# 1.00877464096
# 12.1449683886
# state : 1, new_state : 1, actions : 1, reward :1.00877464096,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  48.56540843]]
# actions : 1
# (1, 1, 1)
# 0.997268271056
# 12.1855785672
# state : 1, new_state : 1, actions : 1, reward :0.997268271056,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  48.65883822]]
# actions : 1
# (1, 1, 1)
# 1.02131520554
# 12.223609583
# state : 1, new_state : 1, actions : 1, reward :1.02131520554,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  48.75172047]]
# actions : 1
# (1, 1, 1)
# 0.991264853492
# 12.2634456868
# state : 1, new_state : 1, actions : 1, reward :0.991264853492,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  48.84404145]]
# actions : 1
# (1, 1, 1)
# 1.00723995369
# 12.3034822081
# state : 1, new_state : 1, actions : 1, reward :1.00723995369,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  48.93582877]]
# actions : 1
# (1, 1, 1)
# 1.00302252885
# 12.3436018031
# state : 1, new_state : 1, actions : 1, reward :1.00302252885,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  49.02709443]]
# actions : 1
# (1, 1, 1)
# 0.983944040638
# 12.3818369083
# state : 1, new_state : 1, actions : 1, reward :0.983944040638,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  49.11784899]]
# actions : 1
# (1, 1, 1)
# 1.01735066542
# 12.4200569763
# state : 1, new_state : 1, actions : 1, reward :1.01735066542,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  49.20808485]]
# actions : 1
# (1, 1, 1)
# 0.981814426308
# 12.4575403622
# state : 1, new_state : 1, actions : 1, reward :0.981814426308,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  49.29781145]]
# actions : 1
# (1, 1, 1)
# 0.997831011635
# 12.4970965778
# state : 1, new_state : 1, actions : 1, reward :0.997831011635,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  49.38703154]]
# actions : 1
# (1, 1, 1)
# 1.00603975995
# 12.5364191274
# state : 1, new_state : 1, actions : 1, reward :1.00603975995,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  49.47577264]]
# actions : 1
# (1, 1, 1)
# 0.993447479296
# 12.5754386436
# state : 1, new_state : 1, actions : 1, reward :0.993447479296,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  49.56404133]]
# actions : 1
# (1, 1, 1)
# 0.973052771482
# 12.6098703496
# state : 1, new_state : 1, actions : 1, reward :0.973052771482,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  49.65184339]]
# actions : 1
# (1, 1, 1)
# 0.982628135215
# 12.6469404956
# state : 1, new_state : 1, actions : 1, reward :0.982628135215,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  49.73914751]]
# actions : 1
# (1, 1, 1)
# 0.99019134238
# 12.685243035
# state : 1, new_state : 1, actions : 1, reward :0.99019134238,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  49.82598497]]
# actions : 1
# (1, 1, 1)
# 1.0069247052
# 12.7238401677
# state : 1, new_state : 1, actions : 1, reward :1.0069247052,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  49.91237433]]
# actions : 1
# (1, 1, 1)
# 1.00140718686
# 12.762571818
# state : 1, new_state : 1, actions : 1, reward :1.00140718686,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  49.99832577]]
# actions : 1
# (1, 1, 1)
# 0.984457254297
# 12.7995553258
# state : 1, new_state : 1, actions : 1, reward :0.984457254297,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  50.0838479 ]]
# actions : 1
# (1, 1, 1)
# 0.992419159863
# 12.8376442172
# state : 1, new_state : 1, actions : 1, reward :0.992419159863,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  50.16893354]]
# actions : 1
# (1, 1, 1)
# 1.00774148422
# 12.8756848124
# state : 1, new_state : 1, actions : 1, reward :1.00774148422,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  50.2535991 ]]
# actions : 1
# (1, 1, 1)
# 1.01217659572
# 12.9130768886
# state : 1, new_state : 1, actions : 1, reward :1.01217659572,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  50.33785117]]
# actions : 1
# (1, 1, 1)
# 1.01453083867
# 12.9499761359
# state : 1, new_state : 1, actions : 1, reward :1.01453083867,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  50.42169136]]
# actions : 1
# (1, 1, 1)
# 1.0021887674
# 12.9879955173
# state : 1, new_state : 1, actions : 1, reward :1.0021887674,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  50.5051225 ]]
# actions : 1
# (1, 1, 1)
# 1.01771453118
# 13.0240446445
# state : 1, new_state : 1, actions : 1, reward :1.01771453118,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  50.58816011]]
# actions : 1
# (1, 1, 1)
# 0.992248231355
# 13.061391868
# state : 1, new_state : 1, actions : 1, reward :0.992248231355,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  50.67079504]]
# actions : 1
# (1, 1, 1)
# 0.994031696684
# 13.0988058925
# state : 1, new_state : 1, actions : 1, reward :0.994031696684,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  50.75304389]]
# actions : 1
# (1, 1, 1)
# 0.991423861481
# 13.1358466221
# state : 1, new_state : 1, actions : 1, reward :0.991423861481,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  50.8349133 ]]
# actions : 1
# (1, 1, 1)
# 0.997000641477
# 13.1732440318
# state : 1, new_state : 1, actions : 1, reward :0.997000641477,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  50.91640638]]
# actions : 1
# (1, 1, 1)
# 1.00289691084
# 13.2105824774
# state : 1, new_state : 1, actions : 1, reward :1.00289691084,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  50.99753175]]
# actions : 1
# (1, 1, 1)
# 0.995960530682
# 13.2477120904
# state : 1, new_state : 1, actions : 1, reward :0.995960530682,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  51.07829468]]
# actions : 1
# (1, 1, 1)
# 1.00659585924
# 13.2846362607
# state : 1, new_state : 1, actions : 1, reward :1.00659585924,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  51.15869917]]
# actions : 1
# (1, 1, 1)
# 1.00712342595
# 13.3214146988
# state : 1, new_state : 1, actions : 1, reward :1.00712342595,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  51.23874918]]
# actions : 1
# (1, 1, 1)
# 0.985341905505
# 13.3568353401
# state : 1, new_state : 1, actions : 1, reward :0.985341905505,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  51.31844901]]
# actions : 1
# (1, 1, 1)
# 0.999398486474
# 13.3936762763
# state : 1, new_state : 1, actions : 1, reward :0.999398486474,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  51.39779396]]
# actions : 1
# (1, 1, 1)
# 0.995403418634
# 13.4302508887
# state : 1, new_state : 1, actions : 1, reward :0.995403418634,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  51.4767997 ]]
# actions : 1
# (1, 1, 1)
# 0.985515654093
# 13.4654094613
# state : 1, new_state : 1, actions : 1, reward :0.985515654093,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  51.55546934]]
# actions : 1
# (1, 1, 1)
# 0.989409974318
# 13.501147624
# state : 1, new_state : 1, actions : 1, reward :0.989409974318,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  51.63379766]]
# actions : 1
# (1, 1, 1)
# 1.0205765405
# 13.5348686373
# state : 1, new_state : 1, actions : 1, reward :1.0205765405,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  51.71179379]]
# actions : 1
# (1, 1, 1)
# 1.00051158114
# 13.5712068839
# state : 1, new_state : 1, actions : 1, reward :1.00051158114,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  51.78944825]]
# actions : 1
# (1, 1, 1)
# 1.00716413221
# 13.6071483431
# state : 1, new_state : 1, actions : 1, reward :1.00716413221,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  51.86678441]]
# actions : 1
# (1, 1, 1)
# 0.993150400828
# 13.6429290562
# state : 1, new_state : 1, actions : 1, reward :0.993150400828,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  51.94380405]]
# actions : 1
# (1, 1, 1)
# 0.979361498614
# 13.6759783343
# state : 1, new_state : 1, actions : 1, reward :0.979361498614,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  52.02051057]]
# actions : 1
# (1, 1, 1)
# 1.00218594867
# 13.7119010443
# state : 1, new_state : 1, actions : 1, reward :1.00218594867,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  52.09688955]]
# actions : 1
# (1, 1, 1)
# 0.995250601053
# 13.7475748817
# state : 1, new_state : 1, actions : 1, reward :0.995250601053,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  52.17296528]]
# actions : 1
# (1, 1, 1)
# 1.00057119871
# 13.7833319548
# state : 1, new_state : 1, actions : 1, reward :1.00057119871,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  52.2487403 ]]
# actions : 1
# (1, 1, 1)
# 1.00688895245
# 13.8187058212
# state : 1, new_state : 1, actions : 1, reward :1.00688895245,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  52.32421932]]
# actions : 1
# (1, 1, 1)
# 1.01483110546
# 13.8528554272
# state : 1, new_state : 1, actions : 1, reward :1.01483110546,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  52.39940384]]
# actions : 1
# (1, 1, 1)
# 0.999399122105
# 13.8883254591
# state : 1, new_state : 1, actions : 1, reward :0.999399122105,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  52.47428975]]
# actions : 1
# (1, 1, 1)
# 1.00748647495
# 13.9233736779
# state : 1, new_state : 1, actions : 1, reward :1.00748647495,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  52.54888982]]
# actions : 1
# (1, 1, 1)
# 1.00729843578
# 13.958351815
# state : 1, new_state : 1, actions : 1, reward :1.00729843578,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  52.62320514]]
# actions : 1
# (1, 1, 1)
# 1.0135051846
# 13.9923990518
# state : 1, new_state : 1, actions : 1, reward :1.0135051846,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  52.69723907]]
# actions : 1
# (1, 1, 1)
# 1.00239089585
# 14.0274921959
# state : 1, new_state : 1, actions : 1, reward :1.00239089585,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  52.77098931]]
# actions : 1
# (1, 1, 1)
# 1.00039086824
# 14.0625197683
# state : 1, new_state : 1, actions : 1, reward :1.00039086824,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  52.84446636]]
# actions : 1
# (1, 1, 1)
# 0.973382083524
# 14.0923322104
# state : 1, new_state : 1, actions : 1, reward :0.973382083524,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  52.91767339]]
# actions : 1
# (1, 1, 1)
# 1.01011863821
# 14.1265272438
# state : 1, new_state : 1, actions : 1, reward :1.01011863821,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  52.99058071]]
# actions : 1
# (1, 1, 1)
# 1.00745768742
# 14.1609462569
# state : 1, new_state : 1, actions : 1, reward :1.00745768742,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  53.06321994]]
# actions : 1
# (1, 1, 1)
# 1.01296380708
# 14.1945401809
# state : 1, new_state : 1, actions : 1, reward :1.01296380708,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  53.13559595]]
# actions : 1
# (1, 1, 1)
# 1.00972739859
# 14.2285408067
# state : 1, new_state : 1, actions : 1, reward :1.00972739859,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  53.20770695]]
# actions : 1
# (1, 1, 1)
# 1.00188114374
# 14.2630266163
# state : 1, new_state : 1, actions : 1, reward :1.00188114374,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  53.27955885]]
# actions : 1
# (1, 1, 1)
# 1.00645500116
# 14.2972038875
# state : 1, new_state : 1, actions : 1, reward :1.00645500116,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  53.35115791]]
# actions : 1
# (1, 1, 1)
# 1.00215611714
# 14.3315186199
# state : 1, new_state : 1, actions : 1, reward :1.00215611714,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  53.42250543]]
# actions : 1
# (1, 1, 1)
# 1.01148733454
# 14.3649450639
# state : 1, new_state : 1, actions : 1, reward :1.01148733454,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  53.49360539]]
# actions : 1
# (1, 1, 1)
# 1.00566972368
# 14.3989381599
# state : 1, new_state : 1, actions : 1, reward :1.00566972368,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  53.56445548]]
# actions : 1
# (1, 1, 1)
# 0.979272476828
# 14.4297500559
# state : 1, new_state : 1, actions : 1, reward :0.979272476828,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  53.6350622 ]]
# actions : 1
# (1, 1, 1)
# 1.01313065448
# 14.4626437797
# state : 1, new_state : 1, actions : 1, reward :1.01313065448,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  53.70540949]]
# actions : 1
# (1, 1, 1)
# 0.994077631069
# 14.496242424
# state : 1, new_state : 1, actions : 1, reward :0.994077631069,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  53.7755129 ]]
# actions : 1
# (1, 1, 1)
# 1.01695952552
# 14.5281917684
# state : 1, new_state : 1, actions : 1, reward :1.01695952552,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  53.84537957]]
# actions : 1
# (1, 1, 1)
# 1.00457701815
# 14.5618387228
# state : 1, new_state : 1, actions : 1, reward :1.00457701815,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  53.91500264]]
# actions : 1
# (1, 1, 1)
# 0.983007784711
# 14.5932483391
# state : 1, new_state : 1, actions : 1, reward :0.983007784711,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  53.98439497]]
# actions : 1
# (1, 1, 1)
# 1.00976242052
# 14.6262503791
# state : 1, new_state : 1, actions : 1, reward :1.00976242052,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  54.0535463 ]]
# actions : 1
# (1, 1, 1)
# 0.982560926647
# 14.6573843168
# state : 1, new_state : 1, actions : 1, reward :0.982560926647,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  54.12246869]]
# actions : 1
# (1, 1, 1)
# 1.00503497269
# 14.6906764381
# state : 1, new_state : 1, actions : 1, reward :1.00503497269,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  54.1911541 ]]
# actions : 1
# (1, 1, 1)
# 1.00311149864
# 14.7239871491
# state : 1, new_state : 1, actions : 1, reward :1.00311149864,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  54.25961763]]
# actions : 1
# (1, 1, 1)
# 0.994326498899
# 14.7569707847
# state : 1, new_state : 1, actions : 1, reward :0.994326498899,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  54.32786199]]
# actions : 1
# (1, 1, 1)
# 1.00774697226
# 14.7898102666
# state : 1, new_state : 1, actions : 1, reward :1.00774697226,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  54.39588785]]
# actions : 1
# (1, 1, 1)
# 0.987950142243
# 14.8217557688
# state : 1, new_state : 1, actions : 1, reward :0.987950142243,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  54.46369693]]
# actions : 1
# (1, 1, 1)
# 0.994380670651
# 14.8545201703
# state : 1, new_state : 1, actions : 1, reward :0.994380670651,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  54.53128671]]
# actions : 1
# (1, 1, 1)
# 0.993645057952
# 14.8871415627
# state : 1, new_state : 1, actions : 1, reward :0.993645057952,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  54.59866424]]
# actions : 1
# (1, 1, 1)
# 1.02040299955
# 14.9171769442
# state : 1, new_state : 1, actions : 1, reward :1.02040299955,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  54.66583114]]
# actions : 1
# (1, 1, 1)
# 1.00865158403
# 14.9495359106
# state : 1, new_state : 1, actions : 1, reward :1.00865158403,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  54.73277556]]
# actions : 1
# (1, 1, 1)
# 0.999855949365
# 14.9822815819
# state : 1, new_state : 1, actions : 1, reward :0.999855949365,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  54.79951271]]
# actions : 1
# (1, 1, 1)
# 1.00773934282
# 15.0145982375
# state : 1, new_state : 1, actions : 1, reward :1.00773934282,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  54.86604698]]
# actions : 1
# (1, 1, 1)
# 1.00787662974
# 15.0468312923
# state : 1, new_state : 1, actions : 1, reward :1.00787662974,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  54.93237831]]
# actions : 1
# (1, 1, 1)
# 1.02547229092
# 15.0748690179
# state : 1, new_state : 1, actions : 1, reward :1.02547229092,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  54.99850848]]
# actions : 1
# (1, 1, 1)
# 1.01758270631
# 15.1052663395
# state : 1, new_state : 1, actions : 1, reward :1.01758270631,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  55.06441727]]
# actions : 1
# (1, 1, 1)
# 1.00161332844
# 15.1376460908
# state : 1, new_state : 1, actions : 1, reward :1.00161332844,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  55.13011964]]
# actions : 1
# (1, 1, 1)
# 1.00163712543
# 15.1699564935
# state : 1, new_state : 1, actions : 1, reward :1.00163712543,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  55.19562832]]
# actions : 1
# (1, 1, 1)
# 1.01225655681
# 15.2012537442
# state : 1, new_state : 1, actions : 1, reward :1.01225655681,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  55.26094503]]
# actions : 1
# (1, 1, 1)
# 0.996500476408
# 15.2332772958
# state : 1, new_state : 1, actions : 1, reward :0.996500476408,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  55.32606653]]
# actions : 1
# (1, 1, 1)
# 1.02278365468
# 15.2618429361
# state : 1, new_state : 1, actions : 1, reward :1.02278365468,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  55.39099869]]
# actions : 1
# (1, 1, 1)
# 0.997350212328
# 15.2937708165
# state : 1, new_state : 1, actions : 1, reward :0.997350212328,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  55.45572559]]
# actions : 1
# (1, 1, 1)
# 0.994546870497
# 15.3254173302
# state : 1, new_state : 1, actions : 1, reward :0.994546870497,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  55.52026675]]
# actions : 1
# (1, 1, 1)
# 1.0003463648
# 15.3573113595
# state : 1, new_state : 1, actions : 1, reward :1.0003463648,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  55.58462267]]
# actions : 1
# (1, 1, 1)
# 0.997772600572
# 15.3890627249
# state : 1, new_state : 1, actions : 1, reward :0.997772600572,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  55.64879655]]
# actions : 1
# (1, 1, 1)
# 1.00591035467
# 15.4206486516
# state : 1, new_state : 1, actions : 1, reward :1.00591035467,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  55.71278956]]
# actions : 1
# (1, 1, 1)
# 1.00956914679
# 15.4518004307
# state : 1, new_state : 1, actions : 1, reward :1.00956914679,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  55.77660273]]
# actions : 1
# (1, 1, 1)
# 1.00854015436
# 15.4830137494
# state : 1, new_state : 1, actions : 1, reward :1.00854015436,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  55.84023575]]
# actions : 1
# (1, 1, 1)
# 1.00278778906
# 15.5145610881
# state : 1, new_state : 1, actions : 1, reward :1.00278778906,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  55.90369076]]
# actions : 1
# (1, 1, 1)
# 1.01309470801
# 15.5449770871
# state : 1, new_state : 1, actions : 1, reward :1.01309470801,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  55.96697124]]
# actions : 1
# (1, 1, 1)
# 1.00940473897
# 15.5758998048
# state : 1, new_state : 1, actions : 1, reward :1.00940473897,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  56.03007336]]
# actions : 1
# (1, 1, 1)
# 1.00045105158
# 15.6072697542
# state : 1, new_state : 1, actions : 1, reward :1.00045105158,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  56.09300142]]
# actions : 1
# (1, 1, 1)
# 0.989756040946
# 15.6375819148
# state : 1, new_state : 1, actions : 1, reward :0.989756040946,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  56.15575936]]
# actions : 1
# (1, 1, 1)
# 1.00254379128
# 15.6688138394
# state : 1, new_state : 1, actions : 1, reward :1.00254379128,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  56.21834372]]
# actions : 1
# (1, 1, 1)
# 0.990583728937
# 15.6991416671
# state : 1, new_state : 1, actions : 1, reward :0.990583728937,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  56.2807607 ]]
# actions : 1
# (1, 1, 1)
# 1.02942855114
# 15.7241143818
# state : 1, new_state : 1, actions : 1, reward :1.02942855114,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  56.34300757]]
# actions : 1
# (1, 1, 1)
# 0.999654766261
# 15.7551428085
# state : 1, new_state : 1, actions : 1, reward :0.999654766261,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  56.40506029]]
# actions : 1
# (1, 1, 1)
# 0.994749052918
# 15.7858064484
# state : 1, new_state : 1, actions : 1, reward :0.994749052918,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  56.46694971]]
# actions : 1
# (1, 1, 1)
# 1.01203892485
# 15.8158257769
# state : 1, new_state : 1, actions : 1, reward :1.01203892485,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  56.52867571]]
# actions : 1
# (1, 1, 1)
# 0.999364267954
# 15.8466615081
# state : 1, new_state : 1, actions : 1, reward :0.999364267954,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  56.5902368 ]]
# actions : 1
# (1, 1, 1)
# 1.00111129432
# 15.8774643316
# state : 1, new_state : 1, actions : 1, reward :1.00111129432,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  56.65163845]]
# actions : 1
# (1, 1, 1)
# 1.00621656035
# 15.9080152134
# state : 1, new_state : 1, actions : 1, reward :1.00621656035,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  56.71288203]]
# actions : 1
# (1, 1, 1)
# 1.00865633891
# 15.9382732496
# state : 1, new_state : 1, actions : 1, reward :1.00865633891,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  56.77396788]]
# actions : 1
# (1, 1, 1)
# 1.00837414611
# 15.9685058178
# state : 1, new_state : 1, actions : 1, reward :1.00837414611,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  56.83489613]]
# actions : 1
# (1, 1, 1)
# 0.996279831098
# 15.9988730274
# state : 1, new_state : 1, actions : 1, reward :0.996279831098,
# Q matrix :
#  [[  5.93111068  21.74408319]
#  [ 18.56396871  56.89566818]]
# actions : 1
# (1, 1, 1)
# 0.993382802495
# 16.0288903391
# ...
# Q matrix :
#  [[  21.56414553  104.87649398]
#  [  88.15598572  120.91261797]]
# actions : 1
# (1, 1, 1)
# 1.00850179963
# 47.9246146096
# state : 1, new_state : 1, actions : 1, reward :1.00850179963,
# Q matrix :
#  [[  21.56414553  104.87649398]
#  [  88.15598572  120.92791654]]
# actions : 1
# (1, 1, 1)
# 1.0081300634
# 47.9315349903
# state : 1, new_state : 1, actions : 1, reward :1.0081300634,
# Q matrix :
#  [[  21.56414553  104.87649398]
#  [  88.15598572  120.94321172]]
# actions : -1
# (1, 0, -1)
# 0.988920819356
# 47.9374765225
# state : 1, new_state : 0, actions : -1, reward :0.988920819356,
# Q matrix :
#  [[  21.56414553  104.87649398]
#  [  88.15598572  120.95850357]]
# actions : 1
# (0, 1, 1)
# 1.0
# 47.9456791251
# state : 0, new_state : 1, actions : 1, reward :1.0,
# Q matrix :
#  [[  21.56414553  104.87649398]
#  [  88.87181897  120.95850357]]
# actions : 1
# (1, 1, 1)
# 1.01479335067
# 47.9496807729
# state : 1, new_state : 1, actions : 1, reward :1.01479335067,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  120.95850357]]
# actions : 1
# (1, 1, 1)
# 1.02114602442
# 47.9493492734
# state : 1, new_state : 1, actions : 1, reward :1.02114602442,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  120.97379618]]
# actions : 1
# (1, 1, 1)
# 0.999177780789
# 47.957536396
# state : 1, new_state : 1, actions : 1, reward :0.999177780789,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  120.98908281]]
# actions : 1
# (1, 1, 1)
# 0.988115823652
# 47.9631199385
# state : 1, new_state : 1, actions : 1, reward :0.988115823652,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.00436658]]
# actions : 1
# (1, 1, 1)
# 0.984494354059
# 47.9668494435
# state : 1, new_state : 1, actions : 1, reward :0.984494354059,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.01964653]]
# actions : 1
# (1, 1, 1)
# 0.972820357859
# 47.9612435878
# state : 1, new_state : 1, actions : 1, reward :0.972820357859,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.03492199]]
# actions : 1
# (1, 1, 1)
# 0.981511099014
# 47.9630833818
# state : 1, new_state : 1, actions : 1, reward :0.981511099014,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.05018957]]
# actions : 1
# (1, 1, 1)
# 1.00645741333
# 47.9704481503
# state : 1, new_state : 1, actions : 1, reward :1.00645741333,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.06545197]]
# actions : 1
# (1, 1, 1)
# 0.997613748027
# 47.9785362682
# state : 1, new_state : 1, actions : 1, reward :0.997613748027,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.08071123]]
# actions : 1
# (1, 1, 1)
# 0.991806228498
# 47.9854954772
# state : 1, new_state : 1, actions : 1, reward :0.991806228498,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.0959676 ]]
# actions : 1
# (1, 1, 1)
# 1.00722586692
# 47.9926528046
# state : 1, new_state : 1, actions : 1, reward :1.00722586692,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.11122067]]
# actions : 1
# (1, 1, 1)
# 1.00200227203
# 48.0007451478
# state : 1, new_state : 1, actions : 1, reward :1.00200227203,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.12647052]]
# actions : 1
# (1, 1, 1)
# 0.997706413297
# 48.0088349359
# state : 1, new_state : 1, actions : 1, reward :0.997706413297,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.1417175 ]]
# actions : 1
# (1, 1, 1)
# 0.979348609227
# 48.0090788934
# state : 1, new_state : 1, actions : 1, reward :0.979348609227,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.15696159]]
# actions : 1
# (1, 1, 1)
# 1.00239896792
# 48.017130032
# state : 1, new_state : 1, actions : 1, reward :1.00239896792,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.17219996]]
# actions : 1
# (1, 1, 1)
# 0.992370746528
# 48.0242458175
# state : 1, new_state : 1, actions : 1, reward :0.992370746528,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.18743544]]
# actions : 1
# (1, 1, 1)
# 1.00323614087
# 48.0322001746
# state : 1, new_state : 1, actions : 1, reward :1.00323614087,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.2026677 ]]
# actions : 1
# (1, 1, 1)
# 1.00731977685
# 48.0393177973
# state : 1, new_state : 1, actions : 1, reward :1.00731977685,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.21789704]]
# actions : 1
# (1, 1, 1)
# 0.994952576093
# 48.0470315453
# state : 1, new_state : 1, actions : 1, reward :0.994952576093,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.23312317]]
# actions : 1
# (1, 1, 1)
# 0.983097789978
# 48.0499016649
# state : 1, new_state : 1, actions : 1, reward :0.983097789978,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.24834629]]
# actions : 1
# (1, 1, 1)
# 1.00092755728
# 48.0580432123
# state : 1, new_state : 1, actions : 1, reward :1.00092755728,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.26356466]]
# actions : 1
# (1, 1, 1)
# 1.00222805543
# 48.0660985746
# state : 1, new_state : 1, actions : 1, reward :1.00222805543,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.27878019]]
# actions : 1
# (1, 1, 1)
# 1.00448593036
# 48.0738538231
# state : 1, new_state : 1, actions : 1, reward :1.00448593036,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.29399286]]
# actions : 1
# (1, 1, 1)
# 0.988654861573
# 48.079647647
# state : 1, new_state : 1, actions : 1, reward :0.988654861573,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.30920254]]
# actions : 1
# (1, 1, 1)
# 1.01114723084
# 48.0853961519
# state : 1, new_state : 1, actions : 1, reward :1.01114723084,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.32440855]]
# actions : 1
# (1, 1, 1)
# 1.00458815279
# 48.0931285187
# state : 1, new_state : 1, actions : 1, reward :1.00458815279,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.33961085]]
# actions : 1
# (1, 1, 1)
# 0.991631271166
# 48.1000069335
# state : 1, new_state : 1, actions : 1, reward :0.991631271166,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.35481018]]
# actions : 1
# (1, 1, 1)
# 0.99717272211
# 48.1080241943
# state : 1, new_state : 1, actions : 1, reward :0.99717272211,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.37000623]]
# actions : 1
# (1, 1, 1)
# 0.990917636685
# 48.114669391
# state : 1, new_state : 1, actions : 1, reward :0.990917636685,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.38519941]]
# actions : 1
# (1, 1, 1)
# 0.989990243902
# 48.1209849727
# state : 1, new_state : 1, actions : 1, reward :0.989990243902,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.40038922]]
# actions : 1
# (1, 1, 1)
# 1.00803550543
# 48.1278658808
# state : 1, new_state : 1, actions : 1, reward :1.00803550543,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.41557556]]
# actions : 1
# (1, 1, 1)
# 0.995815962967
# 48.1357054777
# state : 1, new_state : 1, actions : 1, reward :0.995815962967,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.43075862]]
# actions : 1
# (1, 1, 1)
# 0.993118969149
# 48.1429960655
# state : 1, new_state : 1, actions : 1, reward :0.993118969149,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.44593876]]
# actions : 1
# (1, 1, 1)
# 0.995869790001
# 48.1508413091
# state : 1, new_state : 1, actions : 1, reward :0.995869790001,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.46111578]]
# actions : 1
# (1, 1, 1)
# 1.00648672653
# 48.1581490425
# state : 1, new_state : 1, actions : 1, reward :1.00648672653,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.47628989]]
# actions : 1
# (1, 1, 1)
# 0.991905939567
# 48.1650991911
# state : 1, new_state : 1, actions : 1, reward :0.991905939567,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.49146088]]
# actions : 1
# (1, 1, 1)
# 1.00738131587
# 48.1721637922
# state : 1, new_state : 1, actions : 1, reward :1.00738131587,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.50662864]]
# actions : 1
# (1, 1, 1)
# 0.988371505496
# 48.1778144843
# state : 1, new_state : 1, actions : 1, reward :0.988371505496,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.5217932 ]]
# actions : 1
# (1, 1, 1)
# 1.00169160858
# 48.1858851402
# state : 1, new_state : 1, actions : 1, reward :1.00169160858,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.53695407]]
# actions : 1
# (1, 1, 1)
# 0.994914204078
# 48.1935606286
# state : 1, new_state : 1, actions : 1, reward :0.994914204078,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.55211211]]
# actions : 1
# (1, 1, 1)
# 0.996709192739
# 48.2015081555
# state : 1, new_state : 1, actions : 1, reward :0.996709192739,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.56726718]]
# actions : 1
# (1, 1, 1)
# 1.01052713
# 48.2074793582
# state : 1, new_state : 1, actions : 1, reward :1.01052713,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.58241939]]
# actions : 1
# (1, 1, 1)
# 0.99634978193
# 48.215378402
# state : 1, new_state : 1, actions : 1, reward :0.99634978193,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.59756803]]
# actions : 1
# (1, 1, 1)
# 0.986123180149
# 48.2199492592
# state : 1, new_state : 1, actions : 1, reward :0.986123180149,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.61271379]]
# actions : 1
# (1, 1, 1)
# 0.998864990123
# 48.2280575684
# state : 1, new_state : 1, actions : 1, reward :0.998864990123,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.62785547]]
# actions : 1
# (1, 1, 1)
# 1.00538173903
# 48.235600544
# state : 1, new_state : 1, actions : 1, reward :1.00538173903,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.64299436]]
# actions : 1
# (1, 1, 1)
# 1.01303600346
# 48.2404292997
# state : 1, new_state : 1, actions : 1, reward :1.01303600346,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.65813025]]
# actions : 1
# (1, 1, 1)
# 0.996764372406
# 48.2483715835
# state : 1, new_state : 1, actions : 1, reward :0.996764372406,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.67326217]]
# actions : 1
# (1, 1, 1)
# 0.995515470754
# 48.2561377279
# state : 1, new_state : 1, actions : 1, reward :0.995515470754,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.68839124]]
# actions : -1
# (1, 0, -1)
# 1.01396953129
# 48.2604793816
# state : 1, new_state : 0, actions : -1, reward :1.01396953129,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  88.87181897  121.70351739]]
# actions : 1
# (0, 1, 1)
# 1.0
# 48.2685954537
# state : 0, new_state : 1, actions : 1, reward :1.0,
# Q matrix :
#  [[  21.56414553  105.56672926]
#  [  89.58226008  121.70351739]]
# actions : 1
# (1, 1, 1)
# 0.995571831511
# 48.2763653328
# state : 1, new_state : 1, actions : 1, reward :0.995571831511,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  121.70351739]]
# actions : 1
# (1, 1, 1)
# 1.01672541935
# 48.2790865
# state : 1, new_state : 1, actions : 1, reward :1.01672541935,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  121.7186451 ]]
# actions : 1
# (1, 1, 1)
# 0.986067082697
# 48.2836052364
# state : 1, new_state : 1, actions : 1, reward :0.986067082697,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  121.7337681 ]]
# actions : 1
# (1, 1, 1)
# 1.00157855849
# 48.2916578086
# state : 1, new_state : 1, actions : 1, reward :1.00157855849,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  121.74888702]]
# actions : 1
# (1, 1, 1)
# 1.00897175933
# 48.298189678
# state : 1, new_state : 1, actions : 1, reward :1.00897175933,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  121.76400314]]
# actions : 1
# (1, 1, 1)
# 0.986066352363
# 48.3027028861
# state : 1, new_state : 1, actions : 1, reward :0.986066352363,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  121.77911592]]
# actions : 1
# (1, 1, 1)
# 1.01591940487
# 48.3059177953
# state : 1, new_state : 1, actions : 1, reward :1.01591940487,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  121.79422464]]
# actions : 1
# (1, 1, 1)
# 1.00406761483
# 48.3136833639
# state : 1, new_state : 1, actions : 1, reward :1.00406761483,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  121.80932882]]
# actions : 1
# (1, 1, 1)
# 1.00523053723
# 48.321236488
# state : 1, new_state : 1, actions : 1, reward :1.00523053723,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  121.82443012]]
# actions : 1
# (1, 1, 1)
# 1.00951235404
# 48.3275698866
# state : 1, new_state : 1, actions : 1, reward :1.00951235404,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  121.83952844]]
# actions : 1
# (1, 1, 1)
# 0.983212785602
# 48.3304271592
# state : 1, new_state : 1, actions : 1, reward :0.983212785602,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  121.85462337]]
# actions : 1
# (1, 1, 1)
# 0.990164167965
# 48.3367479393
# state : 1, new_state : 1, actions : 1, reward :0.990164167965,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  121.86971365]]
# actions : 1
# (1, 1, 1)
# 0.997799936507
# 48.3447626853
# state : 1, new_state : 1, actions : 1, reward :0.997799936507,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  121.88480053]]
# actions : 1
# (1, 1, 1)
# 0.991628691671
# 48.3515775266
# state : 1, new_state : 1, actions : 1, reward :0.991628691671,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  121.89988461]]
# actions : 1
# (1, 1, 1)
# 0.99617782147
# 48.3594143376
# state : 1, new_state : 1, actions : 1, reward :0.99617782147,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  121.91496548]]
# actions : 1
# (1, 1, 1)
# 1.005971035
# 48.366792713
# state : 1, new_state : 1, actions : 1, reward :1.005971035,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  121.93004349]]
# actions : 1
# (1, 1, 1)
# 1.00288750432
# 48.3747054457
# state : 1, new_state : 1, actions : 1, reward :1.00288750432,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  121.94511848]]
# actions : 1
# (1, 1, 1)
# 0.986573899583
# 48.3794576747
# state : 1, new_state : 1, actions : 1, reward :0.986573899583,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  121.96019066]]
# actions : 1
# (1, 1, 1)
# 0.989598877727
# 48.3855566097
# state : 1, new_state : 1, actions : 1, reward :0.989598877727,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  121.97525889]]
# actions : 1
# (1, 1, 1)
# 0.985143651134
# 48.3895520791
# state : 1, new_state : 1, actions : 1, reward :0.985143651134,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  121.99032365]]
# actions : 1
# (1, 1, 1)
# 0.975903491083
# 48.3867949316
# state : 1, new_state : 1, actions : 1, reward :0.975903491083,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  122.0053842 ]]
# actions : 1
# (1, 1, 1)
# 1.01311789075
# 48.3915286226
# state : 1, new_state : 1, actions : 1, reward :1.01311789075,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  122.02043815]]
# actions : 1
# (1, 1, 1)
# 1.00547558486
# 48.3990012493
# state : 1, new_state : 1, actions : 1, reward :1.00547558486,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  122.03548815]]
# actions : 1
# (1, 1, 1)
# 0.993674634706
# 48.4063586622
# state : 1, new_state : 1, actions : 1, reward :0.993674634706,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  122.05053519]]
# actions : 1
# (1, 1, 1)
# 1.00188959747
# 48.4143514314
# state : 1, new_state : 1, actions : 1, reward :1.00188959747,
# Q matrix :
#  [[  21.56414553  106.25284935]
#  [  89.58226008  122.06557923]]
# /Users/ericfourrier/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:51: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /Users/ericfourrier/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:69: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /Users/ericfourrier/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:82: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /Users/ericfourrier/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:88: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
sum(model.states == 0)
# Out:
# 102

# %%
model.rewards[1:].cumprod()
# Out:
# array([ 1.        ,  1.        ,  1.        , ...,  0.39576638,
#         0.39326302,  0.39400612])

# %%
model.market_returns
# Out:
# array([ 0.        , -0.01881752, -0.0065672 , ...,  0.00547558,
#        -0.00632537,  0.0018896 ])

# %%
model.rewards[1:].cumprod()
# Out:
# array([ 1.        ,  1.        ,  1.        , ...,  0.39576638,
#         0.39326302,  0.39400612])

# %%
plt.plot(brownian)

# %%
model.simu_transition(-1)
